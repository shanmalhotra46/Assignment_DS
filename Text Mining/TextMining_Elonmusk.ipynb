# %% [markdown]
# ### For Text Mining assignment ONE:1) Perform sentimental analysis on the Elon-musk tweets (Exlon-musk.csv)

# %%
import pandas as pd
import numpy as np
import re 
import string
import nltk
import spacy
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# %%
#pip install spacy
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.11.10)
# Requirement already satisfied: tqdm in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: click in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in d:\data-a\weekdays-11 8to10\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)

# %%
df = pd.read_csv('D:/DATA-DS/assingment/Shan Malhotra DS assingment/Text Mining/Elon_musk.csv',encoding = "latin1")

# %%
df.head(20)
# Out:
#     Unnamed: 0                                               Text
# 0            1                             @kunalb11 Im an alien
# 1            2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2            3                @joerogan @Spotify Great interview!
# 3            4                    @gtera27 Doge is underestimated
# 4            5  @teslacn Congratulations Tesla China for amazi...
# 5            6  Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6            7  Frodo was the underdoge,\nAll thought he would...
# 7            8     @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8            9  @flcnhvy @anonyx10 Indeed! Tweets definitely d...
# 9           10   The most entertaining outcome is the most likely
# 10          11                       @GiveDirectly Just sent some
# 11          12         Just agree to do Clubhouse with @kanyewest
# 12          13                            https://t.co/3rWE9uHSTS
# 13          14     @geoffkeighley @UnrealEngine Its getting real
# 14          15  Bought some Dogecoin for lil X, so he can be a...
# 15          16  @JoshManMode He definitely has issues, but the...
# 16          17                   @freewalletorg Thanks for fixing
# 17          18            @freewalletorg Please unlock my account
# 18          19               @AstroJordy <U+0001F923><U+0001F923>
# 19          20    This is true power haha https://t.co/Fc9uhQSd7O

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Text          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1999 non-null   int64
#  1   Text        1999 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %%
df_stop = pd.read_csv('D:/DATA-DS/assingment/Shan Malhotra DS assingment/Text Mining/stop.txt', encoding = "latin1")

# %%
df_stop.head()
# Out:
#            a
# 0        a's
# 1       able
# 2      about
# 3      above
# 4  according

# %% [markdown]
# DATA CLEANING

# %%
df1=df.copy()

# %%
def text_cleaning(text):
    text = re.sub(r'@[A-Z_a-z_0-9_]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    text = re.sub(r'#', '', text)     
    text = text.lower()
    return text

# %%
df1['Text'] = df['Text'].apply(text_cleaning)

# %%
def thorough_clean(text):
  text = re.sub('[^A-Za-z0-9]', ' ', text)
  return(text)

# %%
df1['Text'] = df1['Text'].apply(text_cleaning)

# %%
freq_uncleaned = pd.Series(' '.join(df1['Text']).split()).value_counts()[:20] 
freq_uncleaned
# Out:
# the      485
# to       399
# a        354
# is       354
# of       314
# &amp;    218
# in       218
# for      193
# will     164
# be       155
# we       135
# this     133
# on       128
# :        128
# rt       127
# it       126
# that     125
# but      119
# i        116
# with     105
# dtype: int64

# %%
df_stop = [a.strip() for a in df_stop.a]
df_stop = [a for a in df_stop if a]
df_stop[0:10]
# Out:
# ["a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards']

# %%
df2=df1.copy()

# %%
df2['Text'] = df1['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in df_stop))

# %%
df2.head(20)
# Out:
#     Unnamed: 0                                               Text
# 0            1                                          im alien
# 1            2          ray tracing cyberpunk hdr next-level. it?
# 2            3                                   great interview!
# 3            4                                doge underestimated
# 4            5  congratulations tesla china amazing execution ...
# 5            6                                     happy year ox!
# 6            7                frodo underdoge, thought fail, all.
# 7            8                                            haha :)
# 8            9  indeed! tweets represent real-world time alloc...
# 9           10                               entertaining outcome
# 10          11
# 11          12                                    agree clubhouse
# 12          13
# 13          14                                          its real
# 14          15            bought dogecoin lil x, a toddler hodler
# 15          16                      issues, sentencing a bit high
# 16          17                                             fixing
# 17          18                                     unlock account
# 18          19                           <u+0001f923><u+0001f923>
# 19          20                                    true power haha

# %%
post_clean_freq = pd.Series(' '.join(df2['Text']).split()).value_counts()[:20]

# %%
post_clean_freq
# Out:
# a                           354
# &amp;                       218
# :                           128
# rt                          127
# tesla                        85
# great                        65
# its                         56
# haha                         47
# good                         44
# launch                       43
# <u+0001f923><u+0001f923>     34
# make                         32
# dragon                       29
# high                         29
# starship                     28
# true                         28
# falcon                       28
# people                       27
# were                        26
# yeah,                        26
# dtype: int64

# %% [markdown]
# Applying count vectorizer

# %%
vectorizer = CountVectorizer(min_df = 1, max_df = 0.9)
X = vectorizer.fit_transform(df2["Text"])
word_freq_df = pd.DataFrame({'term': vectorizer.get_feature_names_out(), 'occurrences':np.asarray(X.sum(axis=0)).ravel().tolist()})
word_freq_df['frequency'] = word_freq_df['occurrences']/np.sum(word_freq_df['occurrences'])

# %% [markdown]
# Applying TF IDF

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_features= 1000, max_df = 0.5, smooth_idf=True) 
doc_vec = vectorizer.fit_transform(df2["Text"])
names_features = vectorizer.get_feature_names_out()
dense = doc_vec.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns = names_features)

# %%
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top2_words = get_top_n2_words(df2["Text"], n=100) 
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head()
# Out:
#              Bi-gram  Freq
# 0  0001f923 0001f923    35
# 1              we re    26
# 2          rt falcon    17
# 3        crew dragon    13
# 4        giga berlin    12

# %%
top10_bigram = top2_df.iloc[0:10,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top10_bigram["Bi-gram"],y=top10_bigram["Freq"])
plot.set_xticklabels(rotation=90,labels = top10_bigram["Bi-gram"])
plt.title("Top words repeatedly used together in tweets by Elon Musk", y=1.05, fontsize=17)
# Out:
# Text(0.5, 1.05, 'Top words repeatedly used together in tweets by Elon Musk')

# %%
def get_top_3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_3_words(df2["Text"], n=100)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]

# %%
top10_trigram = top3_df.iloc[0:10,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top10_trigram["Tri-gram"],y=top10_trigram["Freq"])
plot.set_xticklabels(rotation=90,labels = top10_trigram["Tri-gram"])
plt.title("Top words repeatedly used together in tweets by Elon Musk", y=1.05, fontsize=17)
# Out:
# Text(0.5, 1.05, 'Top words repeatedly used together in tweets by Elon Musk')

# %%
string_Total = " ".join(df2["Text"])

# %%
fig = plt.figure(figsize = (40,30))

wordcloud_stw = WordCloud(
                background_color= 'black',
                colormap='Set1',
                width = 3000,
                height = 2000, random_state = 10, max_font_size = 200
                ).generate(string_Total)
plt.imshow(wordcloud_stw)
plt.title("Most Repeated words by Elon Musk in tweets", y=1.07, fontsize=100)
# Out:
# Text(0.5, 1.07, 'Most Repeated words by Elon Musk in tweets')

# %% [markdown]
# Performing sentimental analysis

# %%
def get_subjectivity(text):
  return TextBlob(text).sentiment.subjectivity

def get_polarity(text):
  return TextBlob(text).sentiment.polarity

df2['subjectivity'] = df2['Text'].apply(get_subjectivity)
df2['polarity'] = df2['Text'].apply(get_polarity)
df2
# Out:
#       Unnamed: 0                                               Text  \
# 0              1                                          im alien
# 1              2          ray tracing cyberpunk hdr next-level. it?
# 2              3                                   great interview!
# 3              4                                doge underestimated
# 4              5  congratulations tesla china amazing execution ...
# ...          ...                                                ...
# 1994        1995  true, sounds surreal, negative propaganda &amp...
# 1995        1996  make read ur terms &amp; conditions clicking a...
# 1996        1997                                     samwise gamgee
# 1997        1998         altho dumb dumber <u+0001f525><u+0001f525>
# 1998        1999                          progress update august 28
#
#       subjectivity  polarity
# 0         0.750000 -0.250000
# 1         0.000000  0.000000
# 2         0.750000  1.000000
# 3         0.000000  0.000000
# 4         0.700000  0.690625
# ...            ...       ...
# 1994      0.508333  0.111111
# 1995      0.000000  0.000000
# 1996      0.000000  0.000000
# 1997      0.500000 -0.375000
# 1998      0.000000  0.000000
#
# [1999 rows x 4 columns]

# %%
def getanalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  elif score > 0:
      return 'Positive'

df2['Analysis'] = df2['polarity'].apply(getanalysis) 
df2
# Out:
#       Unnamed: 0                                               Text  \
# 0              1                                          im alien
# 1              2          ray tracing cyberpunk hdr next-level. it?
# 2              3                                   great interview!
# 3              4                                doge underestimated
# 4              5  congratulations tesla china amazing execution ...
# ...          ...                                                ...
# 1994        1995  true, sounds surreal, negative propaganda &amp...
# 1995        1996  make read ur terms &amp; conditions clicking a...
# 1996        1997                                     samwise gamgee
# 1997        1998         altho dumb dumber <u+0001f525><u+0001f525>
# 1998        1999                          progress update august 28
#
#       subjectivity  polarity  Analysis
# 0         0.750000 -0.250000  Negative
# 1         0.000000  0.000000   Neutral
# 2         0.750000  1.000000  Positive
# 3         0.000000  0.000000   Neutral
# 4         0.700000  0.690625  Positive
# ...            ...       ...       ...
# 1994      0.508333  0.111111  Positive
# 1995      0.000000  0.000000   Neutral
# 1996      0.000000  0.000000   Neutral
# 1997      0.500000 -0.375000  Negative
# 1998      0.000000  0.000000   Neutral
#
# [1999 rows x 5 columns]

# %%
positive_tweets = df2[df2['Analysis'] == 'Positive']
positive_tweets = positive_tweets.sort_values('polarity', ascending = False)
positive_tweets
# Out:
#       Unnamed: 0                                               Text  \
# 2              3                                   great interview!
# 1901        1902           fermi awesome. understood questions ask.
# 1857        1858                                        great shot!
# 1836        1837  impressive tianwen-1 mars rover mission launch...
# 1824        1825                               thats a great idea!
# ...          ...                                                ...
# 1621        1622  rt : spot tiny humans!!! shot puts scale!!! a ...
# 207          208  launching small satellites a wide range custom...
# 150          151  unlike aircraft division, fine, faa space divi...
# 945          946       mobi-c mobility, fusion little. mobi-d haha.
# 203          204  were switching a fsd version numbering distin...
#
#       subjectivity  polarity  Analysis
# 2         0.750000  1.000000  Positive
# 1901      1.000000  1.000000  Positive
# 1857      0.750000  1.000000  Positive
# 1836      1.000000  1.000000  Positive
# 1824      0.750000  1.000000  Positive
# ...            ...       ...       ...
# 1621      0.530556  0.019444  Positive
# 207       0.516667  0.008333  Positive
# 150       0.450000  0.008333  Positive
# 945       0.400000  0.006250  Positive
# 203       0.350000  0.006250  Positive
#
# [658 rows x 5 columns]

# %%
negative_tweets = df2[df2['Analysis'] == 'Negative']
negative_tweets = negative_tweets.sort_values('polarity', ascending = True)
negative_tweets
# Out:
#       Unnamed: 0                                               Text  \
# 1422        1423           boring tunnel vegas a months operational
# 1265        1266                                             insane
# 576          577                 bad! engines make cargo bay propel
# 1660        1661  rt : we moon, a base moon, send people mars make
# 1273        1274  eerie parallels boring company &amp; vault-tec...
# ...          ...                                                ...
# 408          409  unfortunately, pedestrian speaker needed, exte...
# 1349        1350  rt : raptor vacuum engine (rvac) starship ship...
# 971          972                roomy 3 vacuum rocket engines added
# 1416        1417  giant gap experimental medical device patients...
# 746          747  great hear people a lot pcr testing industry. ...
#
#       subjectivity      polarity  Analysis
# 1422      1.000000 -1.000000e+00  Negative
# 1265      1.000000 -1.000000e+00  Negative
# 576       0.666667 -8.750000e-01  Negative
# 1660      1.000000 -8.000000e-01  Negative
# 1273      1.000000 -7.500000e-01  Negative
# ...            ...           ...       ...
# 408       0.400000 -2.500000e-02  Negative
# 1349      0.000000 -8.333333e-03  Negative
# 971       0.000000 -8.333333e-03  Negative
# 1416      0.480000 -5.000000e-03  Negative
# 746       0.650000 -1.850372e-17  Negative
#
# [198 rows x 5 columns]

# %%
plt.figure(figsize=(8,6))
for i in range(0, df2.shape[0]):
  plt.scatter(df2.polarity[i], df2.subjectivity[i], color = 'cyan')

plt.title("Sentiment Analysis")
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
print(" Positive tweets in %", round((positive_tweets.shape[0]/df2.shape[0])*100, 1))
print(" Negative tweets: in %", round((negative_tweets.shape[0]/df2.shape[0])*100, 1))
# Out:
#  Positive tweets in % 32.9
#  Negative tweets: in % 9.9

# %%
plt.figure(figsize=(10,7))
df2['Analysis'].value_counts().plot(kind='bar')
plt.title("Sentiment Analysis")
plt.xlabel('Sentiments')
plt.ylabel('Count')
plt.show()
